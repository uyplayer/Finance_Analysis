# %% [markdown]
# # BTC Price Prediction

# %%
# from utils import *

import time
import numpy as np
import pandas as pd

from mxnet import nd, autograd, gluon
from mxnet.gluon import nn, rnn
import mxnet as mx
import datetime
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.decomposition import PCA

import math
import requests
import json
import os

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

import xgboost as xgb
from sklearn.metrics import accuracy_score

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
context = mx.cpu()
model_ctx = mx.cpu()
mx.random.seed(1719)

# %% [markdown]
# # GET Bitcoin DATA

# %%
#data convert 
def parser(t):
     return datetime.datetime.strptime(t, "%Y-%m-%d")

# %%
btc_df= pd.read_csv('../data/BTC-USD.csv', header=0, parse_dates=[0], date_parser=parser)
# btc_df=btc_df.set_index('Date')
btc_df = btc_df[(btc_df['Date'] > '2014-09-17') & (btc_df['Date'] <= '2021-05-05')]
btc_df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 1 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
# 5 2014-09-22  399.100006  406.915985  397.130005  402.152008  402.152008
#
#        Volume
# 1  34483200.0
# 2  37919700.0
# 3  36863600.0
# 4  26580100.0
# 5  24127600.0

# %%
btc_df.tail()
# Out:
#            Date          Open          High           Low         Close  \
# 2418 2021-05-01  57714.664063  58448.339844  57052.273438  57828.050781
# 2419 2021-05-02  57825.863281  57902.593750  56141.906250  56631.078125
# 2420 2021-05-03  56620.273438  58973.308594  56590.871094  57200.292969
# 2421 2021-05-04  57214.179688  57214.179688  53191.425781  53333.539063
# 2422 2021-05-05  53252.164063  57911.363281  52969.054688  57424.007813
#
#          Adj Close        Volume
# 2418  57828.050781  4.283643e+10
# 2419  56631.078125  3.817741e+10
# 2420  57200.292969  5.171314e+10
# 2421  53333.539063  6.856471e+10
# 2422  57424.007813  6.924132e+10

# %%
# number of data
print("number of day in file : ",len(btc_df))
# Out:
# number of day in file :  2422

# %%
btc_df
# Out:
#            Date          Open          High           Low         Close  \
# 1    2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2    2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3    2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4    2014-09-21    408.084991    412.425995    393.181000    398.821014
# 5    2014-09-22    399.100006    406.915985    397.130005    402.152008
# 6    2014-09-23    402.092010    441.557007    396.196991    435.790985
# 7    2014-09-24    435.751007    436.112000    421.131989    423.204987
# 8    2014-09-25    423.156006    423.519989    409.467987    411.574005
# 9    2014-09-26    411.428986    414.937988    400.009003    404.424988
# 10   2014-09-27    403.556000    406.622986    397.372009    399.519989
# 11   2014-09-28    399.471008    401.016998    374.332001    377.181000
# 12   2014-09-29    376.928009    385.210999    372.239990    375.467010
# 13   2014-09-30    376.088013    390.976990    373.442993    386.944000
# 14   2014-10-01    387.427002    391.378998    380.779999    383.614990
# 15   2014-10-02    383.988007    385.497009    372.946014    375.071991
# 16   2014-10-03    375.181000    377.695007    357.859009    359.511993
# 17   2014-10-04    359.891998    364.487000    325.885986    328.865997
# 18   2014-10-05    328.915985    341.800995    289.295990    320.510010
# 19   2014-10-06    320.389008    345.134003    302.559998    330.079010
# 20   2014-10-07    330.584015    339.247009    320.481995    336.187012
# 21   2014-10-08    336.115997    354.364014    327.187988    352.940002
# 22   2014-10-09    352.747986    382.726013    347.687012    365.026001
# 23   2014-10-10    364.687012    375.066986    352.963013    361.562012
# 24   2014-10-11    361.362000    367.191010    355.950989    362.299011
# 25   2014-10-12    362.605988    379.433014    356.144012    378.549011
# 20      336.187012  4.919990e+07
# 21      352.940002  5.473630e+07
# 22      365.026001  8.364110e+07
# 23      361.562012  4.366570e+07
# 24      362.299011  1.334520e+07
# 25      378.549011  1.755280e+07
# 26      390.414001  3.522140e+07
# 27      400.869995  3.849150e+07
# 28      394.773010  2.526710e+07
# 29      382.556000  2.699000e+07
# 30      383.757996  1.360070e+07
# ...            ...           ...
# 2393  58192.359375  6.605803e+10
# 2394  56048.937500  7.564530e+10
# 2395  58323.953125  5.305386e+10
# 2396  58245.003906  4.665521e+10
# 2397  59793.234375  5.823847e+10
# 2398  60204.964844  4.628025e+10
# 2399  59893.453125  5.182869e+10
# 2400  63503.457031  6.998345e+10
# 2401  63109.695313  7.745178e+10
# 2402  63314.011719  6.095438e+10
# 2403  61572.789063  8.429301e+10
# 2404  60683.820313  6.613876e+10
# 2405  56216.183594  9.746887e+10
# 2406  55724.265625  6.534487e+10
# 2407  56473.031250  6.784932e+10
# 2408  53906.089844  5.492661e+10
# 2409  51762.273438  7.479863e+10
# 2410  51093.652344  8.666867e+10
# 2411  50050.867188  4.901449e+10
# 2412  49004.253906  4.611711e+10
# 2413  54021.753906  5.828404e+10
# 2414  55033.117188  4.944822e+10
# 2415  54824.703125  4.800057e+10
# 2416  53555.109375  4.608893e+10
# 2417  57750.175781  5.239593e+10
# 2418  57828.050781  4.283643e+10
# 2419  56631.078125  3.817741e+10
# 2420  57200.292969  5.171314e+10
# 2421  53333.539063  6.856471e+10
# 2422  57424.007813  6.924132e+10
#
# [2422 rows x 7 columns]

# %%
y_height = max(btc_df['Close'])
plt.figure(figsize=(14,5))
plt.plot(btc_df['Date'], btc_df['Close'], label='Bitcoin Close proce')
plt.vlines(datetime.date(2021,4, 1), 0, y_height, linestyles='--', colors='gray', label='Train/Test data cut-off')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Bitcoin price')
plt.legend()
plt.show()

# %%
num_training_days = int(btc_df.shape[0]*.975)
print('Number of training days: {}. Number of test days: {}.'.format(num_training_days, \
                                                                    btc_df.shape[0]-num_training_days))
# Out:
# Number of training days: 2361. Number of test days: 61.

# %% [markdown]
# # Correlated assets

# %%
# list all files 
for file in os.listdir("../data/correlated assets/"):
    print(file)
# Out:
# Bitcoin price volatility.csv
# ETH-USD.csv
# .DS_Store
# market_dominance_data.csv
# market_dominance_data.json
# Bitcoin network hashrate.csv
# Bitcoin trading volume.csv
# Blockchain blocks size.csv
# Bitcoin mining difficulty.csv
# SP500.csv
# LTC-USD.csv

# %% [markdown]
# ### get assets

# %%
# ETH
eth_df= pd.read_csv('../data/correlated assets/ETH-USD.csv', header=0)
# eth_df=eth_df.set_index('Date')
# eth_df = eth_df.loc["2014-09-17":"2021-05-05"]
# btc_df=btc_df.set_index('Date')
eth_df = eth_df[(eth_df['Date'] > '2014-09-17') & (eth_df['Date'] <= '2021-05-05')]
eth_df.head(3)
# Out:
#          Date      Open     High       Low     Close  Adj Close    Volume
# 0  2015-08-07  2.831620  3.53661  2.521120  2.772120   2.772120  164329.0
# 1  2015-08-08  2.793760  2.79881  0.714725  0.753325   0.753325  674188.0
# 2  2015-08-09  0.706136  0.87981  0.629191  0.701897   0.701897  532170.0

# %%
eth_df.tail(3)
# Out:
#             Date         Open         High          Low        Close  \
# 2096  2021-05-03  2951.175781  3450.037842  2951.175781  3431.086182
# 2097  2021-05-04  3431.131592  3523.585938  3180.742676  3253.629395
# 2098  2021-05-05  3240.554688  3541.462646  3213.101563  3522.783203
#
#         Adj Close        Volume
# 2096  3431.086182  4.917429e+10
# 2097  3253.629395  6.240205e+10
# 2098  3522.783203  4.833420e+10

# %%
# LTC
ltc_df= pd.read_csv('../data/correlated assets/LTC-USD.csv', header=0)
# ltc_df=ltc_df.set_index('Date')
# ltc_df = ltc_df.loc["2014-09-17":"2021-05-05"]
ltc_df = ltc_df[(ltc_df['Date'] > '2014-09-17') & (ltc_df['Date'] <= '2021-05-05')]
ltc_df.head(3)
# Out:
#          Date     Open     High      Low    Close  Adj Close     Volume
# 1  2014-09-18  5.06543  5.06543  4.57996  4.68523    4.68523  4569260.0
# 2  2014-09-19  4.68729  4.75582  4.25435  4.32777    4.32777  3917450.0
# 3  2014-09-20  4.32920  4.61608  4.20219  4.28644    4.28644  5490660.0

# %%
ltc_df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 2418  2021-05-01  271.142670  278.219421  266.631409  276.833527  276.833527
# 2419  2021-05-02  276.960419  277.483459  265.335724  269.104370  269.104370
# 2420  2021-05-03  269.008301  299.300537  268.728973  294.704010  294.704010
# 2421  2021-05-04  294.774261  326.888672  275.464966  306.234497  306.234497
# 2422  2021-05-05  305.177399  359.500153  301.451569  356.037079  356.037079
#
#             Volume
# 2418  3.611806e+09
# 2419  3.118501e+09
# 2420  5.172505e+09
# 2421  1.154125e+10
# 2422  1.318354e+10

# %%
# sp500
sp500_df= pd.read_csv('../data/correlated assets/SP500.csv', header=0)
# sp500_df=sp500_df.set_index('Date')
# sp500_df = sp500_df.loc["2014-09-17":"2021-05-05"]
sp500_df = sp500_df[(sp500_df['Date'] > '2014-09-17') & (sp500_df['Date'] <= '2021-05-05')]
sp500_df.head(3)
# Out:
#              Date     Open     High      Low    Close        Volume
# 36766  2014-09-18  2003.07  2012.34  2003.07  2011.36  1.797411e+09
# 36767  2014-09-19  2012.74  2019.26  2006.59  2010.40  2.711233e+09
# 36768  2014-09-22  2009.08  2009.08  1991.01  1994.29  1.860928e+09

# %%
sp500_df.tail(3)
# Out:
#              Date     Open     High      Low    Close        Volume
# 38432  2021-05-03  4191.98  4209.39  4188.03  4192.66  2.182103e+09
# 38433  2021-05-04  4179.04  4179.04  4128.59  4164.66  2.552420e+09
# 38434  2021-05-05  4177.06  4187.72  4160.94  4167.59  1.769153e+09

# %%
# Bitcoin market capitalization.csv 
def capitalizatio_time(t):
    return t.replace("00:00:00 UTC","")
bmc_df= pd.read_csv('../data/correlated assets/market_dominance_data.csv', header=0)
# bmc_df['Time'] = bmc_df['Time'].apply(lambda x:capitalizatio_time(x))
# bmc_df.columns = ['Date', 'capitalization']
# bmc_df=bmc_df.set_index('Date')
bmc_df = bmc_df[(bmc_df['Date'] > '2014-09-17') & (bmc_df['Date'] <= '2021-05-05')]
bmc_df.tail(3)
# Out:
#             Date  market_dominance
# 2909  2021-05-03             46.02
# 2910  2021-05-04             44.57
# 2911  2021-05-05             43.47

# %%
def blocks_time(t):
    return t.replace("00:00:00 UTC","")
    
# Blockchain blocks size
bbs_df= pd.read_csv('../data/correlated assets/Blockchain blocks size.csv', header=0)
bbs_df['Time'] = bbs_df['Time'].apply(lambda x:blocks_time(x))
bbs_df.columns = ['Date', 'size']
# bbs_df=bbs_df.set_index('Date')
bbs_df = bbs_df[(bbs_df['Date'] > '2014-09-17') & (bbs_df['Date'] <= '2021-05-05')]
bbs_df.tail(3)
# Out:
#              Date           size
# 4098  2020-03-30   729406.659864
# 4099  2020-03-31   704292.993711
# 4100  2020-04-01   490646.250000

# %%
# Bitcoin network hashrate.csv
def hashrate(t):
    return t.replace("00:00:00 UTC","")
bnh_df= pd.read_csv('../data/correlated assets/Bitcoin network hashrate.csv', header=0)
bnh_df['Time'] = bnh_df['Time'].apply(lambda x:blocks_time(x))
bnh_df=bnh_df.rename(columns={'Time': 'Date'})
# bnh_df=bnh_df.set_index('Date')
bnh_df = bnh_df[(bnh_df['Date'] > '2014-09-17') & (bnh_df['Date'] <= '2021-05-05')]
bnh_df.tail(3)
# Out:
#              Date  50BTC.com       AntPool  BTC Guild       BTC.TOP  \
# 4098  2020-03-30         NaN  1.109364e+19        NaN  2.080058e+18
# 4099  2020-03-31         NaN  1.247847e+19        NaN  6.932482e+17
# 4100  2020-04-01         NaN  6.116053e+18        NaN  6.116053e+18
#
#       BTCC Pool  BW.COM  BitFury  BitMinter  Eligius        F2Pool  \
# 4098        NaN     NaN      NaN        NaN      NaN  1.664047e+19
# 4099        NaN     NaN      NaN        NaN      NaN  2.149069e+19
# 4100        NaN     NaN      NaN        NaN      NaN  1.834816e+19
#
#          SlushPool       Unknown        ViaBTC  ghash.io  others
# 4098  4.853469e+18  6.170840e+19  5.546822e+18       NaN     NaN
# 4099  5.545986e+18  6.377883e+19  6.239234e+18       NaN     NaN
# 4100  6.116053e+18  8.562474e+19           NaN       NaN     NaN

# %%
# Bitcoin trading volume
def volume(t):
    return t.replace("00:00:00 UTC","")
btv_df= pd.read_csv('../data/correlated assets/Bitcoin trading volume.csv', header=0)
btv_df['Time'] = btv_df['Time'].apply(lambda x:volume(x))
btv_df=btv_df.rename(columns={'Time': 'Date'})
# btv_df=btv_df.set_index('Date')
btv_df = btv_df[(btv_df['Date'] > '2014-09-17') & (btv_df['Date'] <= '2021-05-05')]
btv_df.tail(3)
# Out:
#              Date      bitfinex     bitstamp  btcchina      coinbase  huobi  \
# 3942  2021-05-02    4136.125341  2979.898592       NaN   8909.099528    NaN
# 3943  2021-05-03    7574.380747  5546.526207       NaN  17395.504432    NaN
# 3944  2021-05-04   10050.894873  9334.800650       NaN  27140.318810    NaN
#
#             kraken  lakebtc  mtgox  okcoin       others
# 3942   4158.370334      NaN    NaN     NaN  2493.361987
# 3943   7497.584522      NaN    NaN     NaN  4262.713938
# 3944  11535.381771      NaN    NaN     NaN  6581.053893

# %%
# Bitcoin price volatility
def volatility(t):
    return t.replace("00:00:00 UTC","")
bpv_df= pd.read_csv('../data/correlated assets/Bitcoin price volatility.csv', header=0)
bpv_df['Time'] = bpv_df['Time'].apply(lambda x:volatility(x))
bpv_df=bpv_df.rename(columns={'Time': 'Date'})
# bpv_df=bpv_df.set_index('Date')
bpv_df = bpv_df[(bpv_df['Date'] > '2014-09-17') & (bpv_df['Date'] <= '2021-05-05')]
bpv_df.tail(3)
# Out:
#              Date  anxbtc  bitbay  bitcoin24  bitcurex  bitfloor  btce  \
# 3911  2021-05-02      NaN     NaN        NaN       NaN       NaN   NaN
# 3912  2021-05-03      NaN     NaN        NaN       NaN       NaN   NaN
# 3913  2021-05-04      NaN     NaN        NaN       NaN       NaN   NaN
#
#       campbx  coinsetter  gatecoin  justcoin  lakebtc  mtgox  okcoin  \
# 3911     NaN         NaN       NaN       NaN      NaN    NaN     NaN
# 3912     NaN         NaN       NaN       NaN      NaN    NaN     NaN
# 3913     NaN         NaN       NaN       NaN      NaN    NaN     NaN
#
#           others  therocktrading
# 3911  786.964035             NaN
# 3912  140.935477             NaN
# 3913  187.732074             NaN

# %%
def get_technical_indicators(dataset):
    # Create 7 and 21 days Moving Average
    dataset['ma7'] = dataset['Close'].rolling(window=7).mean()
    dataset['ma21'] = dataset['Close'].rolling(window=21).mean()
    
    # Create MACD
    dataset['26ema'] = pd.ewma(dataset['Close'], span=26)
    dataset['12ema'] = pd.ewma(dataset['Close'], span=12)
    dataset['MACD'] = (dataset['12ema']-dataset['26ema'])

    # Create Bollinger Bands
    dataset['20sd'] = pd.stats.moments.rolling_std(dataset['Close'],20)
    dataset['upper_band'] = dataset['ma21'] + (dataset['20sd']*2)
    dataset['lower_band'] = dataset['ma21'] - (dataset['20sd']*2)
    
    # Create Exponential moving average
    dataset['ema'] = dataset['Close'].ewm(com=0.5).mean()
    
    # Create Momentum
    dataset['momentum'] = dataset['Close']-1
    dataset['log_momentum'] = dataset['momentum'].apply(np.log) 
    
    return dataset

# %%
TI_df = get_technical_indicators(btc_df)
TI_df.head(20)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 1  2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2  2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3  2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4  2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
# 5  2014-09-22  399.100006  406.915985  397.130005  402.152008  402.152008
# 6  2014-09-23  402.092010  441.557007  396.196991  435.790985  435.790985
# 7  2014-09-24  435.751007  436.112000  421.131989  423.204987  423.204987
# 8  2014-09-25  423.156006  423.519989  409.467987  411.574005  411.574005
# 9  2014-09-26  411.428986  414.937988  400.009003  404.424988  404.424988
# 10 2014-09-27  403.556000  406.622986  397.372009  399.519989  399.519989
# 11 2014-09-28  399.471008  401.016998  374.332001  377.181000  377.181000
# 12 2014-09-29  376.928009  385.210999  372.239990  375.467010  375.467010
# 13 2014-09-30  376.088013  390.976990  373.442993  386.944000  386.944000
# 14 2014-10-01  387.427002  391.378998  380.779999  383.614990  383.614990
# 15 2014-10-02  383.988007  385.497009  372.946014  375.071991  375.071991
    shape_0 = dataset.shape[0]
    xmacd_ = shape_0-last_days
    
    dataset = dataset.iloc[-last_days:, :]
    x_ = range(3, dataset.shape[0])
    x_ =list(dataset.index)
#     print(x_)
    # Plot first subplot
    plt.subplot(2, 1, 1)
    plt.plot(dataset['ma7'],label='MA 7', color='g',linestyle='--')
    plt.plot(dataset['Close'],label='Closing Price', color='b')
    plt.plot(dataset['ma21'],label='MA 21', color='r',linestyle='--')
    plt.plot(dataset['upper_band'],label='Upper Band', color='c')
    plt.plot(dataset['lower_band'],label='Lower Band', color='c')
    plt.fill_between(x_, dataset['lower_band'], dataset['upper_band'], alpha=0.35)
    plt.title('Technical indicators for  Bitcoin - last {} days.'.format(last_days))
    plt.ylabel('USD')
    plt.legend()

    # Plot second subplot
    print(xmacd_)
    plt.subplot(2, 1, 2)
    plt.title('MACD')
    plt.plot(dataset['MACD'],label='MACD', linestyle='-.')
    plt.hlines(max(dataset['MACD']), xmacd_, shape_0, colors='g', linestyles='--')
    plt.hlines(min(dataset['MACD']), xmacd_, shape_0, colors='g', linestyles='--')
    plt.plot(dataset['log_momentum'],label='Momentum', color='b',linestyle='-')

    plt.legend()
    plt.show()

# %%
plot_technical_indicators(btc_df_nona, 400)
# Out:
# 1956

# %% [markdown]
# # Fundamental analysis GET  News about Bitcoin

# %%
# news_btc = pd.read_csv('../data/BTC_tweets.csv')
# news_btc=news_btc.rename(columns={'date': 'Date'})
# news_btc=news_btc.set_index('Date')
# news_btc = news_btc.sort_index()

# %%
# news_btc.head()

# %%
# news_btc.tail()

# %%
# news_btc.groupby('Date')

# %% [markdown]
# # Fourier transforms for trend analysis

# %%
data_FT = btc_df[['Close']]

# %%
data_FT.head()
# Out:
#         Close
# 1  424.440002
# 2  394.795990
# 3  408.903992
# 4  398.821014
# 5  402.152008

# %%
data_FT['Close'].head()
# Out:
# 1    424.440002
# 2    394.795990
# 3    408.903992
# 4    398.821014
# 5    402.152008
# Name: Close, dtype: float64

# %%
data_FT.tail()
# Out:
#              Close
# 2418  57828.050781
# 2419  56631.078125
# 2420  57200.292969
# 2421  53333.539063
# 2422  57424.007813

# %%
# close_fft = np.fft.fft(np.asarray(data_FT['Close'].tolist()))
close_fft = np.fft.fft(np.asarray(data_FT))

# %%
close_fft = np.squeeze(close_fft, 1)
print(close_fft)
# Out:
# [  424.440002+0.j   394.79599 +0.j   408.903992+0.j ... 57200.292969+0.j
#  53333.539063+0.j 57424.007813+0.j]

# %%
fft_df = pd.DataFrame({'fft':close_fft})
fft_df['absolute'] = fft_df['fft'].apply(lambda x: np.abs(x))
fft_df['angle'] = fft_df['fft'].apply(lambda x: np.angle(x))

# %%
fft_df
# Out:
#                           fft      absolute  angle
# 0     (424.44000199999994+0j)    424.440002    0.0
# 1              (394.79599+0j)    394.795990    0.0
# 2             (408.903992+0j)    408.903992    0.0
# 3             (398.821014+0j)    398.821014    0.0
# 4             (402.152008+0j)    402.152008    0.0
# 5             (435.790985+0j)    435.790985    0.0
# 6             (423.204987+0j)    423.204987    0.0
# 7             (411.574005+0j)    411.574005    0.0
# 8             (404.424988+0j)    404.424988    0.0
# 9             (399.519989+0j)    399.519989    0.0
# 10               (377.181+0j)    377.181000    0.0
# 11             (375.46701+0j)    375.467010    0.0
# 12               (386.944+0j)    386.944000    0.0
# 13             (383.61499+0j)    383.614990    0.0
# 14            (375.071991+0j)    375.071991    0.0
# 15            (359.511993+0j)    359.511993    0.0
# 16            (328.865997+0j)    328.865997    0.0
# 17             (320.51001+0j)    320.510010    0.0
# 18             (330.07901+0j)    330.079010    0.0
# 19    (336.18701200000004+0j)    336.187012    0.0
# 20            (352.940002+0j)    352.940002    0.0
# 21    (365.02600099999995+0j)    365.026001    0.0
# 22    (361.56201200000004+0j)    361.562012    0.0
# 23            (362.299011+0j)    362.299011    0.0
# 24            (378.549011+0j)    378.549011    0.0
# 25            (390.414001+0j)    390.414001    0.0
# 26            (400.869995+0j)    400.869995    0.0
# 27             (394.77301+0j)    394.773010    0.0
# 28               (382.556+0j)    382.556000    0.0
# 29            (383.757996+0j)    383.757996    0.0
# ...                       ...           ...    ...
# 2392        (58192.359375+0j)  58192.359375    0.0
# 2393          (56048.9375+0j)  56048.937500    0.0
# 2394        (58323.953125+0j)  58323.953125    0.0
# 2395   (58245.00390599999+0j)  58245.003906    0.0
# 2396        (59793.234375+0j)  59793.234375    0.0
# 2397   (60204.96484400001+0j)  60204.964844    0.0
# 2398        (59893.453125+0j)  59893.453125    0.0
# 2399   (63503.45703099999+0j)  63503.457031    0.0
# 2400        (63109.695313+0j)  63109.695313    0.0
# 2401   (63314.01171900001+0j)  63314.011719    0.0
# 2402        (61572.789063+0j)  61572.789063    0.0
# 2403        (60683.820313+0j)  60683.820313    0.0
# 2404   (56216.18359400001+0j)  56216.183594    0.0
# 2405        (55724.265625+0j)  55724.265625    0.0
# 2406         (56473.03125+0j)  56473.031250    0.0
# 2407   (53906.08984400001+0j)  53906.089844    0.0
# 2408        (51762.273438+0j)  51762.273438    0.0
# 2409        (51093.652344+0j)  51093.652344    0.0
# 2410        (50050.867188+0j)  50050.867188    0.0
# 2411        (49004.253906+0j)  49004.253906    0.0
# 2412   (54021.75390599999+0j)  54021.753906    0.0
# 2413        (55033.117188+0j)  55033.117188    0.0
# 2414        (54824.703125+0j)  54824.703125    0.0
# 2415        (53555.109375+0j)  53555.109375    0.0
# 2416   (57750.17578099999+0j)  57750.175781    0.0
# 2417   (57828.05078099999+0j)  57828.050781    0.0
# 2418        (56631.078125+0j)  56631.078125    0.0
# 2419   (57200.29296900001+0j)  57200.292969    0.0
# 2420        (53333.539063+0j)  53333.539063    0.0
# 2421        (57424.007813+0j)  57424.007813    0.0
#
# [2422 rows x 3 columns]

# %%
plt.figure(figsize=(14, 7), dpi=100)
fft_list = np.asarray(fft_df['fft'].tolist())
for num_ in [3, 6, 9, 100]:
    fft_list_m10= np.copy(fft_list); fft_list_m10[num_:-num_]=0
    plt.plot(np.fft.ifft(fft_list_m10), label='Fourier transform with {} components'.format(num_))
plt.plot(data_FT['Close'],  label='Real')
plt.xlabel('Days')
plt.ylabel('USD')
plt.title('Figure 3: Goldman Sachs (close) stock prices & Fourier transforms')
plt.legend()
plt.show()

# %%
from collections import deque
items = deque(np.asarray(fft_df['absolute'].tolist()))
items.rotate(int(np.floor(len(fft_df)/2)))
plt.figure(figsize=(10, 7), dpi=80)
plt.stem(items)
plt.title('Figure 4: Components of Fourier transforms')
plt.show()

# %% [markdown]
# # ARIMA as a feature

# %%
data_FT['Close'].head()
data_FT.to_csv('../../../Downloads/data_FT.csv',index=False)

# %%
data_FT['Close'].tail()
# Out:
# 2418    57828.050781
# 2419    56631.078125
# 2420    57200.292969
# 2421    53333.539063
# 2422    57424.007813
# Name: Close, dtype: float64

# %%
from statsmodels.tsa.arima.model import ARIMA
from pandas import DataFrame
from pandas import datetime
series = data_FT['Close']
series
# Out:
# 1         424.440002
# 2         394.795990
# 3         408.903992
# 4         398.821014
# 5         402.152008
# 6         435.790985
# 7         423.204987
# 8         411.574005
# 9         404.424988
# 10        399.519989
# 11        377.181000
# 12        375.467010
# 13        386.944000
# 14        383.614990
# 15        375.071991
# 16        359.511993
# 17        328.865997
# 18        320.510010
# 19        330.079010
# 20        336.187012
# 21        352.940002
# 22        365.026001
# 23        361.562012
# 24        362.299011
# 25        378.549011
# 26        390.414001
# 27        400.869995
# 28        394.773010
# 29        382.556000
# 30        383.757996
#             ...
# 2393    58192.359375
# 2394    56048.937500
# 2395    58323.953125
# 2396    58245.003906
# 2397    59793.234375
# 2398    60204.964844
# 2399    59893.453125
# 2400    63503.457031
# 2401    63109.695313
# 2402    63314.011719
# 2403    61572.789063
# 2404    60683.820313
# 2405    56216.183594
# 2406    55724.265625
# 2407    56473.031250
# 2408    53906.089844
# 2409    51762.273438
# 2410    51093.652344
# 2411    50050.867188
# 2412    49004.253906
# 2413    54021.753906
# 2414    55033.117188
# 2415    54824.703125
# 2416    53555.109375
# 2417    57750.175781
# 2418    57828.050781
# 2419    56631.078125
# 2420    57200.292969
# 2421    53333.539063
# 2422    57424.007813
# Name: Close, Length: 2422, dtype: float64

# %%
model = ARIMA(series, order=(5, 1, 0))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 2422
# Model:                 ARIMA(5, 1, 0)   Log Likelihood              -18698.028
# Date:                Mon, 10 May 2021   AIC                          37408.055
# Time:                        17:14:06   BIC                          37442.807
# Sample:                             0   HQIC                         37420.692
#                                - 2422
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0029      0.008     -0.385      0.700      -0.018       0.012
# ar.L2          0.0179      0.007      2.399      0.016       0.003       0.033
# ar.L3          0.0628      0.008      8.158      0.000       0.048       0.078
# ar.L4         -0.0175      0.006     -2.774      0.006      -0.030      -0.005
# ar.L5          0.0308      0.007      4.229      0.000       0.017       0.045
# sigma2      3.075e+05   2078.994    147.929      0.000    3.03e+05    3.12e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            136711.82
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):            4957.56   Skew:                             1.28
# Prob(H) (two-sided):                  0.00   Kurtosis:                        39.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
from pandas.tools.plotting import autocorrelation_plot
autocorrelation_plot(series)
plt.figure(figsize=(10, 7), dpi=80)
plt.show()

# %%
from pandas import read_csv
from pandas import datetime
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error



series = series.

np.isnan(series.any())
# Out:
#   File "<ipython-input-273-425f8f714b16>", line 8
#     series = series.
#                     ^
# SyntaxError: invalid syntax

# %%
X = series.values
X

# %%
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)

# %%
type(test)

# %%
print(np.any(np.isnan(test)))
print(np.all(np.isfinite(test)))
print(np.any(np.isnan(predictions)))
print(np.all(np.isfinite(predictions)))

# %%
# test.tolist()

# %%
# predictions

# %%
t = np.array(test)
t = t.astype('int')
type(t)

# %%
p = np.array(predictions)
p = t.astype('int')
type(p)

# %%
# for i in range(len(t)):
#     print(t[i],p[i])

# %%
error = mean_squared_error(t, p)
print('Test MSE: %.3f' % error)

# %%
plt.figure(figsize=(12, 6), dpi=100)
plt.plot(test, label='Real')
plt.plot(predictions, color='red', label='Predicted')
plt.xlabel('Days')
plt.ylabel('USD')
plt.title('Figure 5: ARIMA model on GS stock')
plt.legend()
plt.show()

# %% [markdown]
# # Statistical checks

# %% [markdown]
# # Feature Engineering

# %%
# btc_df_nona  and  btc_df
print(" btc_df :",len(btc_df)," btc_df_nona:",len(btc_df_nona))
# Out:
#  btc_df : 2422  btc_df_nona: 2356

# %%
btc_df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 1 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
# 5 2014-09-22  399.100006  406.915985  397.130005  402.152008  402.152008
#
#        Volume  ma7  ma21       26ema       12ema      MACD  20sd  upper_band  \
# 1  34483200.0  NaN   NaN  424.440002  424.440002  0.000000   NaN         NaN
# 2  37919700.0  NaN   NaN  409.047919  408.382829 -0.665090   NaN         NaN
# 3  36863600.0  NaN   NaN  408.996207  408.586239 -0.409968   NaN         NaN
# 4  26580100.0  NaN   NaN  406.151668  405.503739 -0.647929   NaN         NaN
# 5  24127600.0  NaN   NaN  405.224130  404.593086 -0.631045   NaN         NaN
#
#    lower_band         ema    momentum  log_momentum
# 1         NaN  424.440002  423.440002      6.048412
# 2         NaN  402.206993  393.795990      5.975833
# 3         NaN  406.843377  407.903992      6.011032
# 4         NaN  401.428282  397.821014      5.986002
# 5         NaN  401.912760  401.152008      5.994340

# %%
btc_df_nona.head()
# Out:
#            Date          Open          High           Low         Close  \
# 21   2014-10-08    336.115997    354.364014    327.187988    352.940002
# 22   2014-10-09    352.747986    382.726013    347.687012    365.026001
# 23   2014-10-10    364.687012    375.066986    352.963013    361.562012
# 24   2014-10-11    361.362000    367.191010    355.950989    362.299011
# 25   2014-10-12    362.605988    379.433014    356.144012    378.549011
# 26   2014-10-13    377.920990    397.226013    368.897003    390.414001
# 27   2014-10-14    391.691986    411.697998    391.324005    400.869995
# 28   2014-10-15    400.954987    402.226990    388.765991    394.773010
# 29   2014-10-16    394.518005    398.807007    373.070007    382.556000
# 30   2014-10-17    382.756012    385.477997    375.389008    383.757996
# 31   2014-10-18    383.976013    395.157990    378.971008    391.441986
# 32   2014-10-19    391.253998    393.938995    386.457001    389.545990
# 33   2014-10-20    389.230988    390.084015    378.252014    382.845001
# 34   2014-10-21    382.420990    392.645996    380.834015    386.475006
# 35   2014-10-22    386.118011    388.575989    382.248993    383.157990
# 36   2014-10-23    382.962006    385.048004    356.446991    358.416992
# 37   2014-10-24    358.591003    364.345001    353.304993    358.345001
# 38   2014-10-25    358.610992    359.860992    342.877014    347.270996
# 39   2014-10-26    347.487000    359.221008    343.931000    354.704010
"""
eth_df  ltc_df sp500_df bmc_df bbs_df bnh_df btv_df bpv_df btc_df_nona fft_df

2014-10-08 -  2021-05-05
eth_df = eth_df[(eth_df['Date'] > '2014-09-17') & (eth_df['Date'] <= '2021-05-05')]
"""
# all = pd.concat([],1)
# Out:
# "\neth_df  ltc_df sp500_df bmc_df bbs_df bnh_df btv_df bpv_df btc_df_nona fft_df\n\n2014-10-08 -  2021-05-05\neth_df = eth_df[(eth_df['Date'] > '2014-09-17') & (eth_df['Date'] <= '2021-05-05')]\n"

# %%
start = '2014-09-17'
end = '2021-05-05'

# %%
eth_df_interval = eth_df[(eth_df['Date'] > start) & (eth_df['Date'] <=end)]
eth_df_interval=eth_df_interval.rename(columns={'Close': 'Close_eth'})

# %%
eth_df_interval.head()
# Out:
#          Date      Open      High       Low  Close_eth  Adj Close     Volume
# 0  2015-08-07  2.831620  3.536610  2.521120   2.772120   2.772120   164329.0
# 1  2015-08-08  2.793760  2.798810  0.714725   0.753325   0.753325   674188.0
# 2  2015-08-09  0.706136  0.879810  0.629191   0.701897   0.701897   532170.0
# 3  2015-08-10  0.713989  0.729854  0.636546   0.708448   0.708448   405283.0
# 4  2015-08-11  0.708087  1.131410  0.663235   1.067860   1.067860  1463100.0

# %%
eth_df_interval.tail()
# Out:
#             Date         Open         High          Low    Close_eth  \
# 2094  2021-05-01  2772.838379  2951.440918  2755.908447  2945.892822
# 2095  2021-05-02  2945.560059  2984.891846  2860.526123  2952.056152
# 2096  2021-05-03  2951.175781  3450.037842  2951.175781  3431.086182
# 2097  2021-05-04  3431.131592  3523.585938  3180.742676  3253.629395
# 2098  2021-05-05  3240.554688  3541.462646  3213.101563  3522.783203
#
#         Adj Close        Volume
# 2094  2945.892822  2.872621e+10
# 2095  2952.056152  2.803201e+10
# 2096  3431.086182  4.917429e+10
# 2097  3253.629395  6.240205e+10
# 2098  3522.783203  4.833420e+10

# %%
ltc_df_interval = ltc_df[(ltc_df['Date'] > start) & (ltc_df['Date'] <=end)]
ltc_df_interval=ltc_df_interval.rename(columns={'Close': 'Close_ltc'})
ltc_df_interval.head()
# Out:
#          Date     Open     High      Low  Close_ltc  Adj Close     Volume
# 1  2014-09-18  5.06543  5.06543  4.57996    4.68523    4.68523  4569260.0
# 2  2014-09-19  4.68729  4.75582  4.25435    4.32777    4.32777  3917450.0
# 3  2014-09-20  4.32920  4.61608  4.20219    4.28644    4.28644  5490660.0
# 4  2014-09-21  4.26307  4.30013  4.15499    4.24592    4.24592  2931220.0
# 5  2014-09-22  4.24593  4.41688  4.21013    4.24235    4.24235  1855960.0

# %%
ltc_df_interval.tail()
# Out:
#             Date        Open        High         Low   Close_ltc   Adj Close  \
# 2418  2021-05-01  271.142670  278.219421  266.631409  276.833527  276.833527
# 2419  2021-05-02  276.960419  277.483459  265.335724  269.104370  269.104370
# 2420  2021-05-03  269.008301  299.300537  268.728973  294.704010  294.704010
# 2421  2021-05-04  294.774261  326.888672  275.464966  306.234497  306.234497
# 2422  2021-05-05  305.177399  359.500153  301.451569  356.037079  356.037079
#
#             Volume
# 2418  3.611806e+09
# 2419  3.118501e+09
# 2420  5.172505e+09
# 2421  1.154125e+10
# 2422  1.318354e+10

# %%
# sp500_df
sp500_df_interval = sp500_df[(sp500_df['Date'] > start) & (sp500_df['Date'] <=end)]
sp500_df_interval=sp500_df_interval.rename(columns={'Close': 'Close_sp500'})
sp500_df_interval.head()
# Out:
#              Date     Open     High      Low  Close_sp500        Volume
# 36766  2014-09-18  2003.07  2012.34  2003.07      2011.36  1.797411e+09
# 36767  2014-09-19  2012.74  2019.26  2006.59      2010.40  2.711233e+09
# 36768  2014-09-22  2009.08  2009.08  1991.01      1994.29  1.860928e+09
# 36769  2014-09-23  1992.78  1995.41  1982.77      1982.77  1.821861e+09
# 36770  2014-09-24  1983.34  1999.79  1978.63      1998.30  1.841028e+09

# %%
sp500_df_interval.tail()
# Out:
#              Date     Open     High      Low  Close_sp500        Volume
# 38430  2021-04-29  4206.14  4218.78  4176.81      4211.47  2.502878e+09
# 38431  2021-04-30  4198.10  4198.10  4174.85      4181.17  2.428163e+09
# 38432  2021-05-03  4191.98  4209.39  4188.03      4192.66  2.182103e+09
# 38433  2021-05-04  4179.04  4179.04  4128.59      4164.66  2.552420e+09
# 38434  2021-05-05  4177.06  4187.72  4160.94      4167.59  1.769153e+09

# %%
bmc_df_interval = bmc_df[(bmc_df['Date'] > start) & (bmc_df['Date'] <=end)]
bmc_df_interval.head()
# Out:
#            Date  market_dominance
# 506  2014-09-18             90.59
# 507  2014-09-19             90.63
# 508  2014-09-20             90.81
# 509  2014-09-21             90.86
# 510  2014-09-22             90.74

# %%
bmc_df_interval.tail()
# Out:
#             Date  market_dominance
# 2907  2021-05-01             47.23
# 2908  2021-05-02             46.36
# 2909  2021-05-03             46.02
# 2910  2021-05-04             44.57
# 2911  2021-05-05             43.47

# %%
bnh_df_interval = bnh_df[(bnh_df['Date'] > start) & (bnh_df['Date'] <=end)]
bnh_df_interval.head()
# Out:
#              Date  50BTC.com       AntPool     BTC Guild  BTC.TOP  BTCC Pool  \
# 2077  2014-09-17         NaN  1.045652e+16  2.091303e+16      NaN        NaN
# 2078  2014-09-18         NaN  2.948319e+15  8.844957e+15      NaN        NaN
# 2079  2014-09-19         NaN  7.436167e+15  1.933404e+16      NaN        NaN
# 2080  2014-09-20         NaN  4.465692e+15  1.488564e+16      NaN        NaN
# 2081  2014-09-21         NaN  1.032304e+16  1.032304e+16      NaN        NaN
#
#       BW.COM       BitFury     BitMinter       Eligius        F2Pool  \
# 2077     NaN  7.468941e+15  2.987576e+15  1.195031e+16  6.572668e+16
# 2078     NaN  1.326744e+16  2.948319e+15  7.370798e+15  6.191470e+16
# 2079     NaN  1.338510e+16           NaN  5.948934e+15  6.246381e+16
# 2080     NaN  1.786277e+16           NaN  1.190851e+16  6.400825e+16
# 2081     NaN  1.327248e+16           NaN  1.179776e+16  6.193822e+16
#
#          SlushPool       Unknown  ViaBTC      ghash.io        others
# 2077  1.344409e+16  4.929501e+16     NaN  5.676395e+16  3.883849e+16
# 2078  1.179328e+16  4.864726e+16     NaN  6.486302e+16  4.127647e+16
# 2079  5.948934e+15  4.312977e+16     NaN  5.056594e+16  4.610424e+16
# 2080  1.041995e+16  3.125984e+16     NaN  6.698538e+16  4.019123e+16
# 2081  1.032304e+16  4.129215e+16     NaN  4.571630e+16  3.686799e+16

# %%
btv_df_interval = btv_df[(btv_df['Date'] > start) & (btv_df['Date'] <=end)]
btv_df_interval.head()
# Out:
#              Date      bitfinex      bitstamp    btcchina  coinbase  \
# 1523  2014-09-17   10015.799231  12472.774379  17752.3225       NaN
# 1524  2014-09-18   40114.679875  22065.884692  31280.9146       NaN
# 1525  2014-09-19   33491.475587  29735.720362  39012.4289       NaN
# 1526  2014-09-20   30699.103941  19916.524935  50168.6081       NaN
# 1527  2014-09-21   19190.669472  14182.715652  39568.2340       NaN
#
#            huobi       kraken     lakebtc  mtgox      okcoin        others
# 1523  17350.1410  1040.909809   7627.0168    NaN   30740.008  23991.306161
# 1524  46852.9175  2674.227933  10660.1979    NaN   87457.009  34812.015419
# 1525  66722.7953  3010.759550  17988.0585    NaN  113295.981  32113.079420
# 1526  69855.2852  1859.551441  22292.1882    NaN  116031.318  22020.891880
# 1527  56262.8984  1209.413631  16721.6522    NaN   90065.786  17796.003626

# %%
bpv_df_interval = bpv_df[(bpv_df['Date'] > start) & (bpv_df['Date'] <=end)]
bpv_df_interval.head()
# Out:
#              Date    anxbtc     bitbay  bitcoin24  bitcurex  bitfloor  \
# 1492  2014-09-17   1.269697   2.269813        NaN       NaN       NaN
# 1493  2014-09-18   2.606746  11.773695        NaN       NaN       NaN
# 1494  2014-09-19   4.786172   4.444951        NaN       NaN       NaN
# 1495  2014-09-20   3.585667   5.868986        NaN       NaN       NaN
# 1496  2014-09-21   2.508895        NaN        NaN       NaN       NaN
#
#           btce    campbx  coinsetter  gatecoin  justcoin   lakebtc  mtgox  \
# 1492  1.121040  2.032911         NaN       NaN  2.757036  0.432743    NaN
# 1493  2.212651  8.043207         NaN       NaN  3.964898  1.538034    NaN
# 1494  2.476309  3.834223         NaN       NaN  3.641910  1.499200    NaN
# 1495  1.951677  2.825174         NaN       NaN  4.219929  1.491508    NaN
# 1496  1.720027  2.326820         NaN       NaN  6.081660  1.060854    NaN
#
#         okcoin    others  therocktrading
# 1492  0.472302  1.450227        1.260113
# 1493  1.502742  2.098323        2.831902
# 1494  1.526733  2.727562        2.785556
# 1495  1.618557  9.963346        2.431175
# 1496  1.110493  4.331835        2.050366

# %%
# fft_df
# fft_df_interval = fft_df[(fft_df['Date'] > start) & (fft_df['Date'] <=end)]
# fft_df_interval.head()

# %%
 all_data = pd.concat([btc_df_nona,eth_df_interval,ltc_df_interval,sp500_df_interval,bmc_df_interval],axis=0)

# %%
all_data.head()
# Out:
#          12ema       20sd       26ema   Adj Close       Close  Close_eth  \
# 21  356.774036  32.993690  369.252179  352.940002  352.940002        NaN
# 22  358.076582  32.975773  368.868567  365.026001  365.026001        NaN
# 23  358.624553  32.394343  368.216240  361.562012  361.562012        NaN
# 24  359.200302  32.093251  367.695863  362.299011  362.299011        NaN
# 25  362.223445  31.454238  368.637261  378.549011  378.549011        NaN
#
#     Close_ltc  Close_sp500                 Date        High     ...      \
# 21        NaN          NaN  2014-10-08 00:00:00  354.364014     ...
# 22        NaN          NaN  2014-10-09 00:00:00  382.726013     ...
# 23        NaN          NaN  2014-10-10 00:00:00  375.066986     ...
# 24        NaN          NaN  2014-10-11 00:00:00  367.191010     ...
# 25        NaN          NaN  2014-10-12 00:00:00  379.433014     ...
#
#           Open      Volume         ema  log_momentum  lower_band        ma21  \
# 21  336.115997  54736300.0  346.577219      5.863461  316.393619  382.380999
# 22  352.747986  83641104.0  358.876407      5.897225  313.600216  379.551761
# 23  364.687012  43665700.0  360.666810      5.887664  313.180505  377.969190
# 24  361.362000  13345200.0  361.754944      5.889706  311.563404  375.749905
# 25  362.605988  17552800.0  372.950989      5.933700  311.876097  374.784572
#
#            ma7  market_dominance    momentum  upper_band
# 21  343.309431               NaN  351.940002  448.368379
# 22  341.874289               NaN  364.026001  445.503306
# 23  342.167149               NaN  360.562012  442.757875
# 24  346.943294               NaN  361.299011  439.936407
# 25  355.234580               NaN  377.549011  437.693047
#
# [5 rows x 22 columns]

# %%
all_data.tail()
# Out:
#       12ema  20sd  26ema  Adj Close  Close  Close_eth  Close_ltc  Close_sp500  \
# 2907    NaN   NaN    NaN        NaN    NaN        NaN        NaN          NaN
# 2908    NaN   NaN    NaN        NaN    NaN        NaN        NaN          NaN
# 2909    NaN   NaN    NaN        NaN    NaN        NaN        NaN          NaN
# 2910    NaN   NaN    NaN        NaN    NaN        NaN        NaN          NaN
# 2911    NaN   NaN    NaN        NaN    NaN        NaN        NaN          NaN
#
#             Date  High     ...      Open  Volume  ema  log_momentum  \
# 2907  2021-05-01   NaN     ...       NaN     NaN  NaN           NaN
# 2908  2021-05-02   NaN     ...       NaN     NaN  NaN           NaN
# 2909  2021-05-03   NaN     ...       NaN     NaN  NaN           NaN
# 2910  2021-05-04   NaN     ...       NaN     NaN  NaN           NaN
# 2911  2021-05-05   NaN     ...       NaN     NaN  NaN           NaN
#
#       lower_band  ma21  ma7  market_dominance  momentum  upper_band
# 2907         NaN   NaN  NaN             47.23       NaN         NaN
# 2908         NaN   NaN  NaN             46.36       NaN         NaN
# 2909         NaN   NaN  NaN             46.02       NaN         NaN
# 2910         NaN   NaN  NaN             44.57       NaN         NaN
# 2911         NaN   NaN  NaN             43.47       NaN         NaN
#
# [5 rows x 22 columns]

# %%
list(all_data.columns)
# Out:
# ['12ema',
#  '20sd',
#  '26ema',
#  'Adj Close',
#  'Close',
#  'Close_eth',
#  'Close_ltc',
#  'Close_sp500',
#  'Date',
#  'High',
#  'Low',
#  'MACD',
#  'Open',
#  'Volume',
#  'ema',
#  'log_momentum',
#  'lower_band',
#  'ma21',
#  'ma7',
#  'market_dominance',
#  'momentum',
#  'upper_band']
